# %%
#basics 1-45:
import os
for item,value in os.environ.items():
  print("{}:{}".format(item,value))
# Out:
# ALLUSERSPROFILE:C:\ProgramData
# APPDATA:C:\Users\anils\AppData\Roaming
# CHROME_CRASHPAD_PIPE_NAME:\\.\pipe\crashpad_7800_EBDGBRSJVPYZMIVF
# COMMONPROGRAMFILES:C:\Program Files\Common Files
# COMMONPROGRAMFILES(X86):C:\Program Files (x86)\Common Files
# COMMONPROGRAMW6432:C:\Program Files\Common Files
# COMPUTERNAME:ANILKUMAR
# COMSPEC:C:\WINDOWS\system32\cmd.exe
# DRIVERDATA:C:\Windows\System32\Drivers\DriverData
# EFC_7184:1
# ELECTRON_RUN_AS_NODE:1
# FPS_BROWSER_APP_PROFILE_STRING:Internet Explorer
# FPS_BROWSER_USER_PROFILE_STRING:Default
# HOMEDRIVE:C:
# HOMEPATH:\Users\anils
# JPY_INTERRUPT_EVENT:1560
# LOCALAPPDATA:C:\Users\anils\AppData\Local
# LOGONSERVER:\\ANILKUMAR
# NUMBER_OF_PROCESSORS:8
# ONEDRIVE:C:\Users\anils\OneDrive
# ONEDRIVECONSUMER:C:\Users\anils\OneDrive
# ORIGINAL_XDG_CURRENT_DESKTOP:undefined
# OS:Windows_NT
# ...

# %%
#basics 1-46:
import os
for data in os.environ:
    print("--"*5)
    print('data')
    print(os.environ[data])
    print("=="*10)
# Out:
# ----------
# data
# C:\ProgramData
# ...
# ----------
# data
# C:\Users\anils\AppData\Roaming
# ...
# ----------
# data
# \\.\pipe\crashpad_7800_EBDGBRSJVPYZMIVF
# ...
# ----------
# data
# C:\Program Files\Common Files
# ...
# ----------
# data
# C:\Program Files (x86)\Common Files
# ...
# ----------
# data
# C:\Program Files\Common Files
# ...
# ----------
# data
# ANILKUMAR
# ...
# ----------
# data
# C:\WINDOWS\system32\cmd.exe
# ...
# ----------
# data
# C:\Windows\System32\Drivers\DriverData
# ...
# ----------
# data
# 1
# ...
# ----------
# data
# 1
# ...
# ----------
# data
# Internet Explorer
# ...
# ----------
# data
# Default
# ...
# ----------
# data
# C:
# ...
# ----------
# data
# \Users\anils
# ...
# ----------
# data
# 1560
# ...
# ----------
# data
# C:\Users\anils\AppData\Local
# ...
# ----------
# data
# \\ANILKUMAR
# ...
# ----------
# data
# 8
# ...
# ----------
# data
# C:\Users\anils\OneDrive
# ...
# ----------
# data
# C:\Users\anils\OneDrive
# ...
# ----------
# data
# undefined
# ...
# ----------
# data
# Windows_NT
# ...
# ----------
# data
# ...

# %%
#import 1-47:
import os
import getpass
print(getpass.getuser())
# Out:
# anils

# %%
#import 1-48:
import socket
ip_name =socket.gethostname()
ip_address= socket.gethostbyname_ex(local_hostname)[2]
print("{}\n{}".format(ip_name,ip_address))
filter_ips=[ip for ip in ip_address()]
first_ip=filter_ips[:1]
print(first_ip[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 import socket
#       2 ip_name =socket.gethostname()
# ----> 3 ip_address= socket.gethostbyname_ex(local_hostname)[2]
#       4 print("{}\n{}".format(ip_name,ip_address))
#       5 filter_ips=[ip for ip in ip_address()]
#
# NameError: name 'local_hostname' is not defined

# %%
#basics 1-49:
num=int(input('enter a number:'))
sum_num=(num*(num+1))/2
print(sum_num)
# Out:
# 91.0

# %%
#basics 1-49:
def height(feet,inch):
  feet_to_cm=30.48
  inch_to_cm=2.54
  height_in_cm=(feet*feet_to_cm)+(inch*inch_to_cm)
  return height_in_cm
height(3,5)
height(5,7)
# Out:
# 170.18

# %%
#basics 1-50:
import math
def triangle(a,b):
  print("the values of{} and{}".format(a,b))
  hype=pow(a,2)+pow(b,2)
  return hype
print(triangle(3,4))
# Out:
# the values of3 and4
# 25

# %%
#basics 1-51:
feet=int(input('Enter your feet value'))
feet_to_inch=feet*12
feet_to_yards=feet*0.3
feet_to_miles=feet*1.89
print("{}inches\n{}yards\n{}miles".format(feet_to_inch,feet_to_yards,feet_to_miles))
# Out:
# 408inches
# 10.2yards
# 64.25999999999999miles
